# %% [markdown]
# <a href="https://colab.research.google.com/github/akshata-data/Pandas/blob/main/class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Salaries.csv")
# Out:
# /tmp/ipykernel_3108/715497070.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/content/Salaries.csv")

# %% [markdown]
# 1.  Display Top 10 Rows of The Dataset

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %% [markdown]
# 2. Check Last 10 Rows of The Dataset

# %%
df.tail(10)
# Out:
#             Id        EmployeeName                JobTitle    BasePay  \
# 116465  116466  Christian J Bowman        Police Officer 2  116023.50
# 116466  116467      Mary C Godfrey        Police Officer 3  118898.18
# 116467  116468     Richard S Burns    Plumber Supervisor 2  120910.08
# 116468  116469     Edward F Yamada      IS Engineer-Senior  126402.51
# 116469  116470     David A Morales      IS Engineer-Senior  127438.24
# 116470  116471     Enrique O Mixco          Deputy Sheriff   94191.00
# 116471  116472       Kelly L Swift        Registered Nurse  114313.80
# 116472  116473     Dennis E Cesena        Police Officer 3  118898.10
# 116473  116474    Jeffrey H Bishop             Electrician   94355.00
# 116474  116475   Ramon R Dominguez  Construction Inspector       9.00
#
#         OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits    Year  \
# 116465      8153.55   6204.67  38167.73  130381.72         168549.45  2014.0
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
df.shape
# Out:
# (116475, 13)

# %% [markdown]
# 4.  Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116475 entries, 0 to 116474
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                116475 non-null  int64
#  1   EmployeeName      116475 non-null  object
#  2   JobTitle          116475 non-null  object
#  3   BasePay           115870 non-null  float64
#  4   OvertimePay       116474 non-null  float64
#  5   OtherPay          116474 non-null  float64
#  6   Benefits          80315 non-null   float64
#  7   TotalPay          116474 non-null  float64
#  8   TotalPayBenefits  116474 non-null  float64
#  9   Year              116474 non-null  float64
#  10  Notes             0 non-null       float64
#  11  Agency            116474 non-null  object
#  12  Status            5943 non-null    object
# dtypes: float64(8), int64(1), object(4)
# memory usage: 11.6+ MB

# %% [markdown]
# 5. Check Null Values In The Dataset

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              1
# OtherPay                 1
# Benefits             36160
# TotalPay                 1
# TotalPayBenefits         1
# Year                     1
# Notes               116475
# Agency                   1
# Status              110532
# dtype: int64

# %% [markdown]
# 6. Drop ID, Notes, Agency, and Status Columns

# %%
df.drop(["Id","Notes","Agency","Status"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %% [markdown]
# 7. Get Overall Statistics About The Dataframe

# %%
df.describe(include="all")
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count        116475            116475  115870.000000  116474.000000
# unique       104572              2129            NaN            NaN
# top       Kevin Lee  Transit Operator            NaN            NaN
# freq             10              4564            NaN            NaN
# mean            NaN               NaN   69709.692915    5551.577023
# std             NaN               NaN   44305.455583   12365.980070
# min             NaN               NaN    -166.010000      -0.010000
# 25%             NaN               NaN   38133.045000       0.000000
# 50%             NaN               NaN   66622.450000       0.000000
# 75%             NaN               NaN  100733.872500    5165.060000
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay      Benefits       TotalPay  TotalPayBenefits  \
# count   116474.000000  80315.000000  116474.000000     116474.000000
# ...

# %% [markdown]
# 8. Find Occurrence of The Employee Names  (Top 5)

# %%
df['EmployeeName'].value_counts().head(5)
# Out:
# EmployeeName
# Kevin Lee      10
# Richard Lee     9
# KEVIN LEE       9
# Stanley Lee     8
# MICHAEL LEE     8
# Name: count, dtype: int64

# %% [markdown]
# 9. Find The Number of Unique Job Titles

# %%
df['JobTitle'].nunique()
# Out:
# 2129

# %% [markdown]
# 10.Total Number of Job Titles Contain Captain

# %%
df['JobTitle'].str.contains("Captain",case=True).sum()
# Out:
# np.int64(406)

# %% [markdown]
# 11. Display All the Employee Names From Fire Department

# %%
df[df['JobTitle'].str.contains("Fire Department",case=False)]["EmployeeName"]
# Out:
# 4              PATRICK GARDNER
# 6                    ALSON LEE
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
#                   ...
# 32623             JAMES BARDEN
# 36162       Joanne Hayes-White
# 72926     Joanne M Hayes-White
# 102303          Robert E Evans
# 110535    Joanne M Hayes-White
# Name: EmployeeName, Length: 226, dtype: object

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 116470                                    Deputy Sheriff
# 116471                                  Registered Nurse
# 116472                                  Police Officer 3
# 116473                                       Electrician
# 116474                            Construction Inspector
# Name: JobTitle, Length: 116475, dtype: object

# %% [markdown]
# 12. Find Minimum, Maximum, and Average BasePay

# %%
print("max value of basepay",df['BasePay'].max())
print("min value of basepay",df['BasePay'].min())
print("average value of basepay",df['BasePay'].mean())
# Out:
# max value of basepay 319275.01
# min value of basepay -166.01
# average value of basepay 69709.69291507725

# %% [markdown]
# 13. Replace 'Not Provided' in EmployeeName' Column to NaN

# %%
import numpy as np
df["EmployeeName"].replace("NaN",np.nan)
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 116470      Enrique O Mixco
# 116471        Kelly L Swift
# 116472      Dennis E Cesena
# 116473     Jeffrey H Bishop
# 116474    Ramon R Dominguez
# Name: EmployeeName, Length: 116475, dtype: object

# %% [markdown]
# 14. Drop The Rows Having 5 Missing Values

# %%
df[df.isnull().sum(axis=1)==5]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %% [markdown]
# 15. Find Job Title of ALBERT PARDINI

# %%
df[df["EmployeeName"].str.contains("Albert Pardini",case=False)]["JobTitle"]
# Out:
# 2        CAPTAIN III (POLICE DEPARTMENT)
# 36519                          Captain 3
# Name: JobTitle, dtype: object

# %% [markdown]
# 16. How Much ALBERT PARDINI Make (Include Benefits)?

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df[df["EmployeeName"].str.contains("Albert Pardini",case=False)]["TotalPayBenefits"]
# Out:
# 2        335279.91
# 36519    253995.29
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# 17.Display Name of The Person Having The Highest BasePay

# %%
df

# %%
df[df["BasePay"]==df["BasePay"].max()]["EmployeeName"]
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 116470      Enrique O Mixco
# 116471        Kelly L Swift
# 116472      Dennis E Cesena
# 116473     Jeffrey H Bishop
# 116474    Ramon R Dominguez
# Name: EmployeeName, Length: 116475, dtype: object

# %%
df.loc[df["BasePay"].idxmax(),"EmployeeName"]
# Out:
# 'NATHANIEL FORD'

# %% [markdown]
# 18.Find Average BasePay of All Employee Per Year

# %%
df['BasePay'].mean()
# Out:
# np.float64(319275.0099999999)

# %% [markdown]
# 19. Find Average BasePay of All Employee Per JobTitle
# bs

# %%
df.groupby("JobTitle")["BasePay"].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     319275.01
# ACCOUNTANT                                        319275.01
# ACCOUNTANT INTERN                                 319275.01
# ACUPUNCTURIST                                     319275.01
# ADMINISTRATIVE ANALYST                            319275.01
#                                                     ...
# X-RAY LABORATORY AIDE                             319275.01
# X-Ray Laboratory Aide                             319275.01
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    319275.01
# Youth Comm Advisor                                319275.01
# ZOO CURATOR                                       319275.01
# Name: BasePay, Length: 2129, dtype: float64

# %% [markdown]
# 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
df.groupby("JobTitle")["BasePay"].mean()["ACCOUNTANT"]
# Out:
# np.float64(319275.01)

# %% [markdown]
# 21. Find Top 5 Most Common Job

# %%
df["JobTitle"].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator    4564
# Registered Nurse    3058
# Special Nurse       2915
# TRANSIT OPERATOR    2388
# Police Officer 3    2171
# Name: count, dtype: int64
